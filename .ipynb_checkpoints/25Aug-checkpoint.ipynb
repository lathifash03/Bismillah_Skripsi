# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.2-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lathifash/myenv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/lathifash/myenv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.2-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 6.4 MB/s  0:00:01m0:00:010:01
# Downloading numpy-2.3.2-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 4.1 MB/s  0:00:01m0:00:0100:01
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# Successfully installed numpy-2.3.2 pandas-2.3.2 pytz-2025.2 tzdata-2025.2

# %%
import json
import pandas as pd

# Buka file JSON di folder dataset
with open("dataset/article_1.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Convert ke DataFrame
df = pd.DataFrame([data])   # pakai list, karena hanya 1 artikel JSON
df.head()
# Out:
#                                               thread  \
# 0  {'uuid': '55bcbf205ecd5cd9752220ac0150e245b842...
#
#                                        uuid  \
# 0  55bcbf205ecd5cd9752220ac0150e245b842fb9a
#
#                                                  url  ord_in_thread  \
# 0  https://www.archyde.com/chart-industries-secur...              0
#
#   parent_url   author                      published  \
# 0       None  archyde  2023-12-28T23:58:00.000+02:00
#
#                                                title  \
# 0  Chart Industries Secures Strategic LNG Contrac...
#
#                                                 text highlightText  ...  \
# 0  2023-12-28 18:53:15 Chart Industries, an Ameri...                ...
#
#   highlightThreadTitle language sentiment  \
# 0                       english  positive
#
#                                           categories  \
# 0  [Science and Technology, Economy, Business and...
#
#                                       external_links external_images  \
# 0  [https://www.globenewswire.com/news-release/20...              []
#
#                                             entities rating  \
# 0  {'persons': [], 'organizations': [{'name': 'ch...   None
#
#                          crawled                        updated
# 0  2023-12-29T00:00:17.315+02:00  2023-12-29T00:00:17.315+02:00
#
# [1 rows x 21 columns]

# %%
import os
import json
import pandas as pd

# Folder tempat file JSON
folder = "./dataset" 

data = []

# Loop dari 1 sampai 1000
for i in range(1, 1001):
    filename = f"article_{i}.json"
    filepath = os.path.join(folder, filename)
    
    if os.path.exists(filepath):
        with open(filepath, "r", encoding="utf-8") as f:
            try:
                article = json.load(f)
                data.append({
                    "title": article.get("title", ""),
                    "text": article.get("text", ""),
                    "published": article.get("published", "")
                })
            except Exception as e:
                print(f"Gagal membaca {filename}: {e}")
    else:
        print(f"File tidak ditemukan: {filename}")

# %%
# Buat DataFrame
df = pd.DataFrame(data, columns=["title", "text", "published"])

# Export ke CSV
df.to_csv("all_articles.csv", index=False, encoding="utf-8")

print("✅ Selesai! Data tersimpan di all_articles.csv")
# Out:
# ✅ Selesai! Data tersimpan di all_articles.csv

# %%
# 50 aja
import os
import json
import pandas as pd

# Folder tempat file JSON
folder = "./dataset" 

data = []

# Loop dari 1 sampai 1000
for i in range(1, 51):
    filename = f"article_{i}.json"
    filepath = os.path.join(folder, filename)
    
    if os.path.exists(filepath):
        with open(filepath, "r", encoding="utf-8") as f:
            try:
                article = json.load(f)
                data.append({
                    "title": article.get("title", ""),
                    "text": article.get("text", ""),
                    "published": article.get("published", "")
                })
            except Exception as e:
                print(f"Gagal membaca {filename}: {e}")
    else:
        print(f"File tidak ditemukan: {filename}")

# %%
# Buat DataFrame 50 aja
df = pd.DataFrame(data, columns=["title", "text", "published"])

# Export ke CSV
df.to_csv("all50_articles.csv", index=False, encoding="utf-8")

print("✅ Selesai! Data tersimpan di all50_articles.csv")
# Out:
# ✅ Selesai! Data tersimpan di all50_articles.csv

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import pandas as pd
from openpyxl import Workbook

# Fungsi konversi ke format prosedural
def convert_to_procedural(text: str, published: str):
    points = []
    if published:  # tambahkan tanggal publikasi
        points.append(f"Artikel ini dipublikasikan pada {published}.")
    sentences = text.split(". ")
    for s in sentences:
        s = s.strip().replace("\n", " ")
        if s:
            if not s.endswith("."):
                s += "."
            points.append(s)
    return points

# 1. Baca CSV aslinya
df = pd.read_csv("all50_articles.csv")

# 2. Konversi ke prosedural
procedural_articles = []
for _, row in df.iterrows():
    procedural = convert_to_procedural(row["text"], row["published"])
    procedural_articles.append({
        "title": row["title"],
        "procedural_text": "\n".join(procedural)
    })

# 3. Simpan ke Excel
wb = Workbook()
ws = wb.active
ws.title = "Procedural Articles"

# header
ws.append(["Title", "Procedural Text"])

# data
for article in procedural_articles:
    ws.append([article["title"], article["procedural_text"]])

wb.save("procedural_articles.xlsx")
print("Selesai! File tersimpan sebagai procedural_articles.xlsx")
# Out:
# Selesai! File tersimpan sebagai procedural_articles.xlsx

# %%
#paired 1

import pandas as pd
df = pd.read_csv("all_articles.csv")

# Bersihkan teks kosong
df = df.dropna(subset=["text"]).copy()
df["word_count"] = df["text"].str.split().str.len()

# Filter panjang wajar
sample_pool = df.query("word_count >= 150 and word_count <= 1200")

# Ambil 100 sampel acak
sample = sample_pool.sample(n=100, random_state=42).reset_index(drop=True)

# Siapkan kolom template anotasi
sample = sample.rename(columns={"text":"descriptive_text"})
sample["procedural_steps"] = ""   # nanti diisi anotator (format: JSON array string)
sample["notes"] = ""

sample.to_csv("paired_to_label.csv", index=False)

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("all_articles.csv")

# Ambil 50 artikel acak
sample_df = df.sample(n=50, random_state=42)

# %%
# Experimental Setup
sample_size = 20 news_articles
llm_model = "deepseek-chat"  # atau ChatGPT
evaluation_metrics = {
    'factual_accuracy': [],
    'format_consistency': [], 
    'information_completeness': []
}
